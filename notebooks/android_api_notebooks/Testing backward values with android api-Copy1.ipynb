# %%
import pandas as pd
import numpy as np
from sklearn import model_selection
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn import preprocessing

rest1 = pd.read_csv("../../data_files/case_studies_data/rest-5-minutes.csv")
rest2 = pd.read_csv("../../data_files/case_studies_data/rest_5_all_minutes.csv")
rest3 = pd.read_csv("../../data_files/case_studies_data/rest_5_minutes_2.csv")
rest_val = pd.read_csv("../../data_files/case_studies_data/rest_5_minutes_3.csv")
rest_test = pd.read_csv("../../data_files/case_studies_data/rest_5_minutes_4.csv")

rest_android = pd.read_csv("../../data_files/data_from_android_api/rest/rest_25_mins.csv")

# forward_android4 = pd.read_csv("../../data_files/data_from_android_api/forward_10mins.csv")
# forward_android5 = pd.read_csv("../../data_files/data_from_android_api/forward_90sec.csv")

back1 = pd.read_csv('../../data_files/data_from_android_api/back/back_5mins_1.csv')
back2 = pd.read_csv('../../data_files/data_from_android_api/back/back_5mins_2.csv')
back3 = pd.read_csv('../../data_files/data_from_android_api/back/back_5mins_3.csv')
back4 = pd.read_csv('../../data_files/data_from_android_api/back/back_5mins_4.csv')
back5 = pd.read_csv('../../data_files/data_from_android_api/back/back_5mins_5.csv')

rest = pd.concat([rest1, rest2, rest3, rest_val, rest_test])
back = pd.concat([back1, back2, back3, back4, back5])

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 

r = [rest.delta.mean(), rest.theta.mean(), rest.alphaLow.mean(), 
     rest.alphaHigh.mean(), rest.betaLow.mean(), rest.betaHigh.mean(), 
     rest.gammaLow.mean(), rest.gammaMid.mean()]

ra = [rest_android.delta.mean(), rest_android.theta.mean(), rest_android.alphaLow.mean(), 
     rest_android.alphaHigh.mean(), rest_android.betaLow.mean(), rest_android.betaHigh.mean(), 
     rest_android.gammaLow.mean(), rest_android.gammaMid.mean()]


index = ['delta', 'theta', 'alphaLow','alphaHigh', 'betaLow', 'betaHigh', 'gammaLow', 'gammaMid']

df = pd.DataFrame({'rest original': r,'rest_android': ra}, index=index)
ax = df.plot.bar(rot=0, figsize=(20,10))

# %%
r = [rest.gammaLow.mean(), rest.gammaMid.mean()]

ra = [rest_android.gammaLow.mean(), rest_android.gammaMid.mean()]


index = ['gammaLow', 'gammaMid']

df = pd.DataFrame({'rest original': r,'rest_android': ra}, index=index)
ax = df.plot.bar(rot=0, figsize=(20,10))

# %%
new_rest1 = pd.read_csv("../../data_files/serial_connection_on_mac_recordings/rest.csv")
new_rest2 = pd.read_csv("../../data_files/serial_connection_on_mac_recordings/rest2.csv")
new_rest3 = pd.read_csv("../../data_files/serial_connection_on_mac_recordings/rest3.csv")
new_rest4 = pd.read_csv("../../data_files/serial_connection_on_mac_recordings/rest_17ishmins.csv")
new_rest = pd.concat([new_rest1, new_rest2, new_rest3, new_rest4])

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 

r = [rest.delta.mean(), rest.theta.mean(), rest.alphaLow.mean(), 
     rest.alphaHigh.mean(), rest.betaLow.mean(), rest.betaHigh.mean(), 
     rest.gammaLow.mean(), rest.gammaMid.mean()]

ra = [new_rest.delta.mean(), new_rest.theta.mean(), new_rest.alphaLow.mean(), 
     new_rest.alphaHigh.mean(), new_rest.betaLow.mean(), new_rest.betaHigh.mean(), 
     new_rest.gammaLow.mean(), new_rest.gammaMid.mean()]


index = ['delta', 'theta', 'alphaLow','alphaHigh', 'betaLow', 'betaHigh', 'gammaLow', 'gammaMid']

df = pd.DataFrame({'rest original': r,'rest_computer': ra}, index=index)
ax = df.plot.bar(rot=0, figsize=(20,10))

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 

r = [rest.delta.mean(), rest.theta.mean(), rest.alphaLow.mean(), 
     rest.alphaHigh.mean(), rest.betaLow.mean(), rest.betaHigh.mean(), 
     rest.gammaLow.mean(), rest.gammaMid.mean()]

ra = [rest_android.delta.mean(), rest_android.theta.mean(), rest_android.alphaLow.mean(), 
     rest_android.alphaHigh.mean(), rest_android.betaLow.mean(), rest_android.betaHigh.mean(), 
     rest_android.gammaLow.mean(), rest_android.gammaMid.mean()]


index = ['delta', 'theta', 'alphaLow','alphaHigh', 'betaLow', 'betaHigh', 'gammaLow', 'gammaMid']

df = pd.DataFrame({'rest original': r,'rest_android': ra}, index=index)
ax = df.plot.bar(rot=0, figsize=(20,10))

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 

f = [back.delta.mean(), back.theta.mean(), back.alphaLow.mean(), 
     back.alphaHigh.mean(), back.betaLow.mean(), back.betaHigh.mean(), 
     back.gammaLow.mean(), back.gammaMid.mean()]

ra = [rest_android.delta.mean(), rest_android.theta.mean(), rest_android.alphaLow.mean(), 
     rest_android.alphaHigh.mean(), rest_android.betaLow.mean(), rest_android.betaHigh.mean(), 
     rest_android.gammaLow.mean(), rest_android.gammaMid.mean()]


index = ['delta', 'theta', 'alphaLow','alphaHigh', 'betaLow', 'betaHigh', 'gammaLow', 'gammaMid']

df = pd.DataFrame({'rest_android': ra, 'backward': f}, index=index)
ax = df.plot.bar(rot=0, figsize=(20,10))

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 

f = [back.alphaHigh.mean(), back.betaLow.mean(), back.betaHigh.mean(), 
     back.gammaLow.mean(), back.gammaMid.mean()]

ra = [rest_android.alphaHigh.mean(), rest_android.betaLow.mean(), rest_android.betaHigh.mean(), 
     rest_android.gammaLow.mean(), rest_android.gammaMid.mean()]


index = ['alphaHigh', 'betaLow', 'betaHigh', 'gammaLow', 'gammaMid']

df = pd.DataFrame({'rest_android': ra, 'back': f}, index=index)
ax = df.plot.bar(rot=0, figsize=(20,10))

# %% [markdown]
# # Switched alphaHigh and betaHigh

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 

f = [back.delta.mean(), back.theta.mean(), back.alphaLow.mean(), 
     back.betaHigh.mean(), back.betaLow.mean(), back.alphaHigh.mean(), 
     back.gammaLow.mean(), back.gammaMid.mean()]

ra = [rest_android.delta.mean(), rest_android.theta.mean(), rest_android.alphaLow.mean(), 
     rest_android.betaHigh.mean(), rest_android.betaLow.mean(), rest_android.alphaHigh.mean(), 
     rest_android.gammaLow.mean(), rest_android.gammaMid.mean()]


index = ['delta', 'theta', 'alphaLow','alphaHigh', 'betaLow', 'betaHigh', 'gammaLow', 'gammaMid']

df = pd.DataFrame({'rest_android': ra, 'back': f}, index=index)
ax = df.plot.bar(rot=0, figsize=(20,10))

# %%
f = [back.betaHigh.mean(), back.betaLow.mean(), back.alphaHigh.mean(), 
     back.gammaLow.mean(), back.gammaMid.mean()]

ra = [rest_android.betaHigh.mean(), rest_android.betaLow.mean(), rest_android.alphaHigh.mean(), 
     rest_android.gammaLow.mean(), rest_android.gammaMid.mean()]


index = ['alphaHigh', 'betaLow', 'betaHigh', 'gammaLow', 'gammaMid']

df = pd.DataFrame({'rest_android': ra, 'back': f}, index=index)
ax = df.plot.bar(rot=0, figsize=(20,10))

# %% [markdown]
# # First recording of forward showed better results, fatigue??

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 

f1 = [back1.delta.mean(), back1.theta.mean(), back1.alphaLow.mean(), 
     back1.betaHigh.mean(), back1.betaLow.mean(), back1.alphaHigh.mean(), 
     back1.gammaLow.mean(), back1.gammaMid.mean()]

f2 = [back2.delta.mean(), back2.theta.mean(), back2.alphaLow.mean(), 
     back2.betaHigh.mean(), back2.betaLow.mean(), back2.alphaHigh.mean(), 
     back2.gammaLow.mean(), back2.gammaMid.mean()]

f3 = [back3.delta.mean(), back3.theta.mean(), back3.alphaLow.mean(), 
     back3.betaHigh.mean(), back3.betaLow.mean(), back3.alphaHigh.mean(), 
     back3.gammaLow.mean(), back3.gammaMid.mean()]

f4 = [back4.delta.mean(), back4.theta.mean(), back4.alphaLow.mean(), 
     back4.betaHigh.mean(), back4.betaLow.mean(), back4.alphaHigh.mean(), 
     back4.gammaLow.mean(), back4.gammaMid.mean()]

f5 = [back5.delta.mean(), back5.theta.mean(), back5.alphaLow.mean(), 
     back5.betaHigh.mean(), back5.betaLow.mean(), back5.alphaHigh.mean(), 
     back5.gammaLow.mean(), back5.gammaMid.mean()]



index = ['delta', 'theta', 'alphaLow','alphaHigh', 'betaLow', 'betaHigh', 'gammaLow', 'gammaMid']

df = pd.DataFrame({'back1': f1, 'back2': f2, 
                   'back3': f3, 'back4': f4
                  , 'back5': f5}, index=index)
ax = df.plot.bar(rot=0, figsize=(20,10))
