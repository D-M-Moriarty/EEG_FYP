# %%
import pandas as pd
import numpy as np
from sklearn import model_selection
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn import preprocessing

rest1 = pd.read_csv("../data_files/case_studies_data/rest-5-minutes.csv")
rest2 = pd.read_csv("../data_files/case_studies_data/rest_5_all_minutes.csv")
rest3 = pd.read_csv("../data_files/case_studies_data/rest_5_minutes_2.csv")
rest_val = pd.read_csv("../data_files/case_studies_data/rest_5_minutes_3.csv")
rest_test = pd.read_csv("../data_files/case_studies_data/rest_5_minutes_4.csv")

rest_android = pd.read_csv("../data_files/data_from_android_api/rest_25_mins.csv")

forward_android1 = pd.read_csv("../data_files/data_from_android_api/forward_5mins_1.csv")
forward_android2 = pd.read_csv("../data_files/data_from_android_api/forward_5mins_2.csv")

rest = pd.concat([rest1, rest2, rest3, rest_val, rest_test])
forward = pd.concat([forward_android1, forward_android2])

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 

r = [rest.delta.mean(), rest.theta.mean(), rest.alphaLow.mean(), 
     rest.alphaHigh.mean(), rest.betaLow.mean(), rest.betaHigh.mean(), 
     rest.gammaLow.mean(), rest.gammaMid.mean()]

ra = [rest_android.delta.mean(), rest_android.theta.mean(), rest_android.alphaLow.mean(), 
     rest_android.alphaHigh.mean(), rest_android.betaLow.mean(), rest_android.betaHigh.mean(), 
     rest_android.gammaLow.mean(), rest_android.gammaMid.mean()]


index = ['delta', 'theta', 'alphaLow','alphaHigh', 'betaLow', 'betaHigh', 'gammaLow', 'gammaMid']

df = pd.DataFrame({'rest original': r,'rest_android': ra}, index=index)
ax = df.plot.bar(rot=0, figsize=(20,10))

# %%
r = [rest.gammaLow.mean(), rest.gammaMid.mean()]

ra = [rest_android.gammaLow.mean(), rest_android.gammaMid.mean()]


index = ['gammaLow', 'gammaMid']

df = pd.DataFrame({'rest original': r,'rest_android': ra}, index=index)
ax = df.plot.bar(rot=0, figsize=(20,10))

# %%
rest_android
# Out:
#          delta     theta  alphaLow  alphaHigh   betaLow  betaHigh  gammaLow  \
# 0       732349    111391    680242      21170     89478     91992     23248
# 1       276818      3224     14239      10757      5014     21929      1355
# 2       992384  16748792     45387      17561     14818  16766997      6884
# 3       262064      6148      4760       1334      2024      2566       704
# 4       632464      2912     22227       4570      6104      3882       860
# 5       112524      7887     29659       1602      7004      2665       704
# 6      1633691     15406  16749146       4635     26013     14721      2576
# 7      2068348  16750065     52828       6347     20907  16763143      3339
# 8       527320  16767695     67989   16754069  16754701  16768314     20441
# 9       790643     30270    329821      14756     26679     15956      4353
# 10      828065  16748471     80004      12466     23313     22009      4153
# 11     1912953     29435     74762       5369     25840      6759      1559
# 12    16776897     14895  16759200       1107     11554      1839      1150
# 13    16774562     24546     12006       5759     25152     65941       783
# 14       53801     16904     27548        973      1247     10756  16777205
# 15       59157  16755737  16744559       5622      8229  16753067      2831
# 16      151765     71781  16766720       2946     13833     11777      3334
# 17    16776993     88562     15221       1875      3144     19858       941
# 18    16758130  16775141     22028       3012     19603     20175      1542
# 19       94060     15302  16751463       1821      3887      4044      2280
# 20      284224     34508     62065       3008      6984     19237       758
# 21       45063      5901     19586        814      3197      3740       557
# 22    16749730    149462     20387       2832     13294     12374       496
# 23    16766349     27681     44220       1664      6786      8402      1625
# 24       29853  16749499  16756401       1264      2510  16765434      2045
# 25    16765713     78319     13006       2423      2115      7069      1702
# 26      327075     14105     86562       2140      2340  16751346      1142
# 27      542676  16756988     93820       1715      5301     43987      2510
# 28       49011     22418     22732        691      2966     13250       510
# 29    16775655      3934     15207       2782      3431     12347       214
# ...        ...       ...       ...        ...       ...       ...       ...
# 1514  16759141     16693     22561       2602      4457     31765      1347
# 1515    144949     18845     18394       4921     17359      9305       136
# 1516     69953     29661     12315       2840      5180     26487      1186
# 1517     28009     14355  16768925       2802      4060     12988       652
# 1518  16760537      9616     23266       2341     15191  16759096      1000
# 1519      8260  16754150     30256       3891      3166     13941      2441
# 1520     12608      5267     26608       3468     11796     12101      2296
# 1521     24185  16754338     18369       2188     15939     10060       594
# 1522  16748739     11414  16747222       2326     12363     17350      2127
# 1523     54189  16745910     17380       4117      6532     12731      2106
# 1524  16744885     13542  16748420       5281     17964  16746456      1298
# 1525    484108  16762134     83728       2022      7717     19854       821
# 1526     27828     75108     24729       1965      5152      7157      2585
# 1527  16758917  16764616  16756279       3841      8299     10661       281
# 1528    204642  16766509     23445       2563      7833     21285      1816
# 1529  16763235     31957     27031       2255      5730     10229       994
# 1530     13622  16745229     79526       5715     12013     20322      1241
# 1531     10615  16748720     14407       1930      5343     18239      1394
# 1532     28529  16751991  16757221       5489     11657     35534      1586
# 1533    474543  16754786  16755900       4719     10450     20911      7790
# 1534    866252      8232  16745863       6406      1017      2921       708
# 1535    618706     17917    227089       8520     31532     10312      5921
# 1536     88430     10143     27451       1904     11625      8658      1133
# 1537  16764278     66144  16750314       3458      5568     20826      1992
# 1538     49973      4293     15470       1339      2079      5978       550
# 1539     28961  16758606  16771741       3984      7702     19033      1877
# 1540     26048  16751001     18288       3875     16552     18888      1865
# 1541  16767742     22818  16770899       3608      3346     19378      2977
# 1542     72942     11549      4349       3808      6180     30402      3619
# 1543     61775      2116     16806       1151      1909      1491       340
#
#       gammaMid
# 0        29914
# 1         7207
# 2        18280
# 3         2121
# 4         7409
# 5         2502
# 6        17868
# 7        15876
# 8        69600
# 9        15326
# 10       14645
# 11        7169
# 12        1803
# 13        9810
# 14        1584
# 15        3328
# 16        9097
# 17        4921
# 18        8956
# 19        7580
# 20        5336
# 21        2643
# 22        6067
# 23        4722
# 24        7352
# 25        2615
# 26        4915
# 27        7556
# 28        1887
# 29        1563
# ...        ...
# 1514     11070
# 1515      8748
# 1516      5661
# 1517      5156
# 1518      8687
# 1519      5668
# 1520      5465
# 1521     10545
# 1522     12736
# 1523      4574
# 1524      4447
# 1525     11866
# 1526      6706
# 1527      5066
# 1528     14058
# 1529      3903
# 1530     10626
# 1531      2302
# 1532      6205
# 1533      4877
# 1534      4098
# 1535      8236
# 1536      5979
# 1537      7307
# 1538      1257
# 1539      7000
# 1540      7754
# 1541      3204
# 1542     10739
# 1543      1398
#
# [1544 rows x 8 columns]

# %%
new_rest1 = pd.read_csv("../data_files/serial_connection_on_mac_recordings/rest.csv")
new_rest2 = pd.read_csv("../data_files/serial_connection_on_mac_recordings/rest2.csv")
new_rest3 = pd.read_csv("../data_files/serial_connection_on_mac_recordings/rest3.csv")
new_rest4 = pd.read_csv("../data_files/serial_connection_on_mac_recordings/rest_17ishmins.csv")
new_rest = pd.concat([new_rest1, new_rest2, new_rest3, new_rest4])

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 

r = [rest.delta.mean(), rest.theta.mean(), rest.alphaLow.mean(), 
     rest.alphaHigh.mean(), rest.betaLow.mean(), rest.betaHigh.mean(), 
     rest.gammaLow.mean(), rest.gammaMid.mean()]

ra = [new_rest.delta.mean(), new_rest.theta.mean(), new_rest.alphaLow.mean(), 
     new_rest.alphaHigh.mean(), new_rest.betaLow.mean(), new_rest.betaHigh.mean(), 
     new_rest.gammaLow.mean(), new_rest.gammaMid.mean()]


index = ['delta', 'theta', 'alphaLow','alphaHigh', 'betaLow', 'betaHigh', 'gammaLow', 'gammaMid']

df = pd.DataFrame({'rest original': r,'rest_computer': ra}, index=index)
ax = df.plot.bar(rot=0, figsize=(20,10))

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 

r = [rest.delta.mean(), rest.theta.mean(), rest.alphaLow.mean(), 
     rest.alphaHigh.mean(), rest.betaLow.mean(), rest.betaHigh.mean(), 
     rest.gammaLow.mean(), rest.gammaMid.mean()]

ra = [rest_android.delta.mean(), rest_android.theta.mean(), rest_android.alphaLow.mean(), 
     rest_android.alphaHigh.mean(), rest_android.betaLow.mean(), rest_android.betaHigh.mean(), 
     rest_android.gammaLow.mean(), rest_android.gammaMid.mean()]


index = ['delta', 'theta', 'alphaLow','alphaHigh', 'betaLow', 'betaHigh', 'gammaLow', 'gammaMid']

df = pd.DataFrame({'rest original': r,'rest_android': ra}, index=index)
ax = df.plot.bar(rot=0, figsize=(20,10))

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 

f = [forward.delta.mean(), forward.theta.mean(), forward.alphaLow.mean(), 
     forward.alphaHigh.mean(), forward.betaLow.mean(), forward.betaHigh.mean(), 
     forward.gammaLow.mean(), forward.gammaMid.mean()]

ra = [rest_android.delta.mean(), rest_android.theta.mean(), rest_android.alphaLow.mean(), 
     rest_android.alphaHigh.mean(), rest_android.betaLow.mean(), rest_android.betaHigh.mean(), 
     rest_android.gammaLow.mean(), rest_android.gammaMid.mean()]


index = ['delta', 'theta', 'alphaLow','alphaHigh', 'betaLow', 'betaHigh', 'gammaLow', 'gammaMid']

df = pd.DataFrame({'rest_android': ra, 'forward_android': f}, index=index)
ax = df.plot.bar(rot=0, figsize=(20,10))

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 

f = [forward.alphaHigh.mean(), forward.betaLow.mean(), forward.betaHigh.mean(), 
     forward.gammaLow.mean(), forward.gammaMid.mean()]

ra = [rest_android.alphaHigh.mean(), rest_android.betaLow.mean(), rest_android.betaHigh.mean(), 
     rest_android.gammaLow.mean(), rest_android.gammaMid.mean()]


index = ['alphaHigh', 'betaLow', 'betaHigh', 'gammaLow', 'gammaMid']

df = pd.DataFrame({'rest_android': ra, 'forward_android': f}, index=index)
ax = df.plot.bar(rot=0, figsize=(20,10))

# %%
forward_android
# Out:
#         delta     theta  alphaLow  alphaHigh   betaLow  betaHigh  gammaLow  \
# 0      293486    169847  16770347      28759     28307      7008      5211
# 1      219927     84627  16749408   16772985  16750406  16744828     17577
# 2     1223538     69243      5978      19828      5765      4607      3275
# 3       52759  16759937  16776059      23453  16774798  16757682     15741
# 4        5739     15953     10187      29948  16774325     18815      9419
# 5      215041     57860  16763132      26369     22267     24313     21687
# 6     2052855     39016     11030       7417     13363     11244      2012
# 7    16765651      9242      2000        150       781       200  16777098
# 8     2037932    289261  16770585   16758528     30784     10510     10734
# 9       61363     83369     20732      16505     15144     19571     12883
# 10     592572    120216     28655      21028     12709     24572      9073
# 11     134127  16748918  16754281      17581     13246     11078      8138
# 12     293604  16771535     15658       7123     19350     16013     24509
# 13      77960     25705     13122      24836     21131     11761      4394
# 14     207248     57129     16958      21315      8068     20435     16810
# 15    1821386    825469     50588      82967     26606  16752023  16746778
# 16   16769609  16771380      9432      12781      2119     20897      4431
# 17    1081516     79028     28831      30755     19268     22765     11620
# 18     581381    350650  16745257   16755767     13513  16757361     13160
# 19     172381  16753914      6636       3932      3321      5606      5117
# 20     920716  16774011     14117      19309     20324     15251      3968
# 21     383981  16758689     31533      20811     19424     27931     16965
# 22     588625     13326      4897      10695      1762      6215      3911
# 23      52697      5808      1290      10457      4529      4148      3262
# 24     549209    171244  16748068      12073      8095     16633      7079
# 25     134680  16769617     16364   16757702      5290     19911      8530
# 26     887120    112729  16747040   16764006     24045     13322      9949
# 27     293665  16748678      6712   16751318      3868     12406      5060
# 28   16772803    144204      9660      23365     16085     11861     10705
# 29     131136  16749205      5251      15664     11739      7184      2804
# ..        ...       ...       ...        ...       ...       ...       ...
# 304    758467    102796     31350      18513     21029     12474     29431
# 305    428113     99034  16768669   16762216      8240     27818     12760
# 306    619591     66476      2476       9013      7091      6475      6297
# 307     29621     28312     23015      17445     26703     20308     27257
# 308    955137     33122     11770       2502      2022     12108      5672
# 309     16705      8879      7696       3711      3325      5350      2143
# 310    882366    178361  16757824       7920      9557     15138     29589
# 311    335561  16750290      3598       9697      3799      8682      6549
# 312    131290  16771033     17778       5261     18052     20185     22275
# 313   1429315     75005      5009      14551     21116     13457     22259
# 314    419322     67360  16747185       7957      9877     16141     24530
# 315  16773714     15664      2012        742      1051      2260      3307
# 316   1336475     36163      6899       4460      3453     10276     18875
# 317   1674584    269512     46755      32536     14043     28115  16770888
# 318    173654     84187     18943   16761138  16750389     14870     16157
# 319    140337     11951      9817       5205      2916      2695     13172
# 320  16755770    143675     26412      11577      8630     16207     12769
# 321     53963     25288      4314       6452      8242      5317      1950
# 322    346594     85935     18679      30464      8301      6185      3806
# 323    967694    132501     12650      22059      5796     10857      3035
# 324   1509506     30098     14061       9107      5651      7238      4976
# 325    389830     42404     24753      15110     12075     25872     21444
# 326    903531    225690     16654   16751083      7297     11018     14876
# 327   1123057     94789      3014       2589      4132      5754      5871
# 328   1170750  16766466      6111       9700      4093      3609      5018
# 329    198779     89352      2965       6112      8690     16928      3476
# 330    484001  16769222     10263      28467     10677     10595      4465
# 331    278401     54015      9168      12748      8303     10943     13783
# 332     11632     27456      7398      19404      8496  16744932     12734
# 333      1422     14597     12291      14824      6424     11544      6086
#
#      gammaMid
# 0        5725
# 1       11853
# 2        1360
# 3       13406
# 4        7534
# 5        3428
# 6         654
# 7    16777119
# 8        4948
# 9        5764
# 10       3989
# 11      11957
# 12       6628
# 13       6189
# 14       6362
# 15      22134
# 16       3399
# 17       6448
# 18      12826
# 19       1134
# 20       4520
# 21      19034
# 22       2098
# 23       7225
# 24       7676
# 25       6946
# 26       8311
# 27       3847
# 28       8872
# 29       1102
# ..        ...
# 304      3933
# 305      7515
# 306      1037
# 307      5555
# 308      3590
# 309      1053
# 310     18803
# 311      2138
# 312      7445
# 313     10950
# 314     12033
# 315       655
# 316      5525
# 317     12551
# 318     14386
# 319      4263
# 320      4051
# 321      1878
# 322      4599
# 323      2808
# 324      1355
# 325      7984
# 326      8798
# 327      3997
# 328      2450
# 329      4136
# 330      2819
# 331      3507
# 332      3212
# 333      6168
#
# [334 rows x 8 columns]

# %% [markdown]
# # Switched alphaHigh and betaHigh

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 

f = [forward.delta.mean(), forward.theta.mean(), forward.alphaLow.mean(), 
     forward.betaHigh.mean(), forward.betaLow.mean(), forward.alphaHigh.mean(), 
     forward.gammaLow.mean(), forward.gammaMid.mean()]

ra = [rest_android.delta.mean(), rest_android.theta.mean(), rest_android.alphaLow.mean(), 
     rest_android.betaHigh.mean(), rest_android.betaLow.mean(), rest_android.alphaHigh.mean(), 
     rest_android.gammaLow.mean(), rest_android.gammaMid.mean()]


index = ['delta', 'theta', 'alphaLow','alphaHigh', 'betaLow', 'betaHigh', 'gammaLow', 'gammaMid']

df = pd.DataFrame({'rest_android': ra, 'forward_android': f}, index=index)
ax = df.plot.bar(rot=0, figsize=(20,10))

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 

f = [forward.betaHigh.mean(), forward.betaLow.mean(), forward.alphaHigh.mean(), 
     forward.gammaLow.mean(), forward.gammaMid.mean()]

ra = [rest_android.betaHigh.mean(), rest_android.betaLow.mean(), rest_android.alphaHigh.mean(), 
     rest_android.gammaLow.mean(), rest_android.gammaMid.mean()]


index = ['alphaHigh', 'betaLow', 'betaHigh', 'gammaLow', 'gammaMid']

df = pd.DataFrame({'rest_android': ra, 'forward_android': f}, index=index)
ax = df.plot.bar(rot=0, figsize=(20,10))
