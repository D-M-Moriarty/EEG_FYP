# %%
import pandas as pd
import numpy as np
from sklearn import model_selection
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn import preprocessing

rest1 = pd.read_csv("../../data_files/case_studies_data/rest-5-minutes.csv")
rest2 = pd.read_csv("../../data_files/case_studies_data/rest_5_all_minutes.csv")
rest3 = pd.read_csv("../../data_files/case_studies_data/rest_5_minutes_2.csv")
rest_val = pd.read_csv("../../data_files/case_studies_data/rest_5_minutes_3.csv")
rest_test = pd.read_csv("../../data_files/case_studies_data/rest_5_minutes_4.csv")

rest_android = pd.read_csv("../../data_files/data_from_android_api/rest_25_mins.csv")

forward_android1 = pd.read_csv("../../data_files/data_from_android_api/forward_5mins_1.csv")
forward_android2 = pd.read_csv("../../data_files/data_from_android_api/forward_5mins_2.csv")
forward_android3 = pd.read_csv("../../data_files/data_from_android_api/forward_5mins_3.csv")
forward_android4 = pd.read_csv("../../data_files/data_from_android_api/forward_10mins.csv")

rest = pd.concat([rest1, rest2, rest3, rest_val, rest_test])
forward = pd.concat([forward_android1, forward_android2, forward_android3, forward_android4])
# Out:
# /Users/darrenmoriarty/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:23: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
forward
# Out:
#       action  alphaHigh  alphaLow  betaHigh   betaLow     delta  gammaLow  \
# 0    forward      28759  16770347      7008     28307    293486      5211
# 1    forward   16772985  16749408  16744828  16750406    219927     17577
# 2    forward      19828      5978      4607      5765   1223538      3275
# 3    forward      23453  16776059  16757682  16774798     52759     15741
# 4    forward      29948     10187     18815  16774325      5739      9419
# 5    forward      26369  16763132     24313     22267    215041     21687
# 6    forward       7417     11030     11244     13363   2052855      2012
# 7    forward        150      2000       200       781  16765651  16777098
# 8    forward   16758528  16770585     10510     30784   2037932     10734
# 9    forward      16505     20732     19571     15144     61363     12883
# 10   forward      21028     28655     24572     12709    592572      9073
# 11   forward      17581  16754281     11078     13246    134127      8138
# 12   forward       7123     15658     16013     19350    293604     24509
# 13   forward      24836     13122     11761     21131     77960      4394
# 14   forward      21315     16958     20435      8068    207248     16810
# 15   forward      82967     50588  16752023     26606   1821386  16746778
# 16   forward      12781      9432     20897      2119  16769609      4431
# 17   forward      30755     28831     22765     19268   1081516     11620
# 18   forward   16755767  16745257  16757361     13513    581381     13160
# 19   forward       3932      6636      5606      3321    172381      5117
# 20   forward      19309     14117     15251     20324    920716      3968
# 21   forward      20811     31533     27931     19424    383981     16965
# 22   forward      10695      4897      6215      1762    588625      3911
# 23   forward      10457      1290      4148      4529     52697      3262
# 24   forward      12073  16748068     16633      8095    549209      7079
# 25   forward   16757702     16364     19911      5290    134680      8530
# 26   forward   16764006  16747040     13322     24045    887120      9949
# 27   forward   16751318      6712     12406      3868    293665      5060
# 28   forward      23365      9660     11861     16085  16772803     10705
# 29   forward      15664      5251      7184     11739    131136      2804
# ..       ...        ...       ...       ...       ...       ...       ...
# 591      NaN       5011     32399     16642     16799    215615     14536
# 592      NaN       2289       431      2385      1798     72517      2977
# 593      NaN      19400     10931     23574     10712    352270     11073
# 594      NaN      31201      8107     11296  16754936     17498      6552
# 595      NaN        495      4476      8137       491     69328      3341
# 596      NaN      16008     15634      4715      3828    629469      5672
# 597      NaN       8833      7343      5401       367     46764      5522
# 598      NaN      26970      7222     11551     20793    458469     15577
# 599      NaN       9545     23972      6635      3387    461016      5316
# 600      NaN      31319     29218     20217     11011    205015  16752682
# 601      NaN      66461     31740     15857  16752574     89534     16625
# 602      NaN      23839     15533  16771778     22867    307669     20781
# 603      NaN   16752236  16776634     18044  16746269    496240     31790
# 604      NaN      23086  16746113     11662     20624   1111554     11155
# 605      NaN      19741      9001     29743     15734     16753      6208
# 606      NaN      20544  16747590      8834     17511    355847     14620
# 607      NaN      30008      7869     12023     19751  16762507      9471
# 608      NaN       4333  16762080      7479     15290    479135     13086
# 609      NaN   16764385      4240     17463      4632  16752552     19769
# 610      NaN      17497      7921     10927     21577     56649     16856
# 611      NaN   16772747      5911     12333     17866     24847      3520
# 612      NaN      24423      5180     21912     13275    470882      7185
# 613      NaN   16756111      7905      8252     11220    110775     11402
# 614      NaN      19735     23546     19528  16748154  16752409      9166
# 615      NaN      21740     11412     27671      9446      6979      5958
# 616      NaN      32006     28311  16746397  16745311    389735     29058
# 617      NaN   16773641  16744334     21871     15995     75499     18216
# 618      NaN      67352     26190      9121     15617    273079     17115
# 619      NaN   16756386     10546     17178     17592     21303     26683
# 620      NaN      11833      5336     12168      9797  16763576      7831
#
#      gammaMid     theta
# 0        5725    169847
# 1       11853     84627
# 2        1360     69243
# 3       13406  16759937
# 4        7534     15953
# 5        3428     57860
# 6         654     39016
# 7    16777119      9242
# 8        4948    289261
# 9        5764     83369
# 10       3989    120216
# 11      11957  16748918
# 12       6628  16771535
# 13       6189     25705
# 14       6362     57129
# 15      22134    825469
# 16       3399  16771380
# 17       6448     79028
# 18      12826    350650
# 19       1134  16753914
# 20       4520  16774011
# 21      19034  16758689
# 22       2098     13326
# 23       7225      5808
# 24       7676    171244
# 25       6946  16769617
# 26       8311    112729
# 27       3847  16748678
# 28       8872    144204
# 29       1102  16749205
# ..        ...       ...
# 591      4669  16760424
# 592       754      9064
# 593      8786     42943
# 594      2796  16745314
# 595      1390     11041
# 596      1957     20071
# 597      1503     15770
# 598      7090  16772766
# 599      3662     86740
# 600     16929  16763505
# 601     14393    115680
# 602      9096     47953
# 603     22754    128409
# 604      3204    159906
# 605      9385  16747982
# 606      1857  16762485
# 607      4103      8889
# 608     10008     37624
# 609      7946     11554
# 610      9454  16761953
# 611      3919     17726
# 612      4790     72896
# 613      2489  16775664
# 614      4853     76432
# 615     10894      9495
# 616     13958    268547
# 617      4144  16773489
# 618      4641    188627
# 619      7230     25470
# 620      2691  16748229
#
# [1625 rows x 9 columns]

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 

r = [rest.delta.mean(), rest.theta.mean(), rest.alphaLow.mean(), 
     rest.alphaHigh.mean(), rest.betaLow.mean(), rest.betaHigh.mean(), 
     rest.gammaLow.mean(), rest.gammaMid.mean()]

ra = [rest_android.delta.mean(), rest_android.theta.mean(), rest_android.alphaLow.mean(), 
     rest_android.alphaHigh.mean(), rest_android.betaLow.mean(), rest_android.betaHigh.mean(), 
     rest_android.gammaLow.mean(), rest_android.gammaMid.mean()]


index = ['delta', 'theta', 'alphaLow','alphaHigh', 'betaLow', 'betaHigh', 'gammaLow', 'gammaMid']

df = pd.DataFrame({'rest original': r,'rest_android': ra}, index=index)
ax = df.plot.bar(rot=0, figsize=(20,10))

# %%
r = [rest.gammaLow.mean(), rest.gammaMid.mean()]

ra = [rest_android.gammaLow.mean(), rest_android.gammaMid.mean()]


index = ['gammaLow', 'gammaMid']

df = pd.DataFrame({'rest original': r,'rest_android': ra}, index=index)
ax = df.plot.bar(rot=0, figsize=(20,10))

# %%
new_rest1 = pd.read_csv("../data_files/serial_connection_on_mac_recordings/rest.csv")
new_rest2 = pd.read_csv("../data_files/serial_connection_on_mac_recordings/rest2.csv")
new_rest3 = pd.read_csv("../data_files/serial_connection_on_mac_recordings/rest3.csv")
new_rest4 = pd.read_csv("../data_files/serial_connection_on_mac_recordings/rest_17ishmins.csv")
new_rest = pd.concat([new_rest1, new_rest2, new_rest3, new_rest4])

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 

r = [rest.delta.mean(), rest.theta.mean(), rest.alphaLow.mean(), 
     rest.alphaHigh.mean(), rest.betaLow.mean(), rest.betaHigh.mean(), 
     rest.gammaLow.mean(), rest.gammaMid.mean()]

ra = [new_rest.delta.mean(), new_rest.theta.mean(), new_rest.alphaLow.mean(), 
     new_rest.alphaHigh.mean(), new_rest.betaLow.mean(), new_rest.betaHigh.mean(), 
     new_rest.gammaLow.mean(), new_rest.gammaMid.mean()]


index = ['delta', 'theta', 'alphaLow','alphaHigh', 'betaLow', 'betaHigh', 'gammaLow', 'gammaMid']

df = pd.DataFrame({'rest original': r,'rest_computer': ra}, index=index)
ax = df.plot.bar(rot=0, figsize=(20,10))

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 

r = [rest.delta.mean(), rest.theta.mean(), rest.alphaLow.mean(), 
     rest.alphaHigh.mean(), rest.betaLow.mean(), rest.betaHigh.mean(), 
     rest.gammaLow.mean(), rest.gammaMid.mean()]

ra = [rest_android.delta.mean(), rest_android.theta.mean(), rest_android.alphaLow.mean(), 
     rest_android.alphaHigh.mean(), rest_android.betaLow.mean(), rest_android.betaHigh.mean(), 
     rest_android.gammaLow.mean(), rest_android.gammaMid.mean()]


index = ['delta', 'theta', 'alphaLow','alphaHigh', 'betaLow', 'betaHigh', 'gammaLow', 'gammaMid']

df = pd.DataFrame({'rest original': r,'rest_android': ra}, index=index)
ax = df.plot.bar(rot=0, figsize=(20,10))

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 

f = [forward.delta.mean(), forward.theta.mean(), forward.alphaLow.mean(), 
     forward.alphaHigh.mean(), forward.betaLow.mean(), forward.betaHigh.mean(), 
     forward.gammaLow.mean(), forward.gammaMid.mean()]

ra = [rest_android.delta.mean(), rest_android.theta.mean(), rest_android.alphaLow.mean(), 
     rest_android.alphaHigh.mean(), rest_android.betaLow.mean(), rest_android.betaHigh.mean(), 
     rest_android.gammaLow.mean(), rest_android.gammaMid.mean()]


index = ['delta', 'theta', 'alphaLow','alphaHigh', 'betaLow', 'betaHigh', 'gammaLow', 'gammaMid']

df = pd.DataFrame({'rest_android': ra, 'forward_android': f}, index=index)
ax = df.plot.bar(rot=0, figsize=(20,10))

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 

f = [forward.alphaHigh.mean(), forward.betaLow.mean(), forward.betaHigh.mean(), 
     forward.gammaLow.mean(), forward.gammaMid.mean()]

ra = [rest_android.alphaHigh.mean(), rest_android.betaLow.mean(), rest_android.betaHigh.mean(), 
     rest_android.gammaLow.mean(), rest_android.gammaMid.mean()]


index = ['alphaHigh', 'betaLow', 'betaHigh', 'gammaLow', 'gammaMid']

df = pd.DataFrame({'rest_android': ra, 'forward_android': f}, index=index)
ax = df.plot.bar(rot=0, figsize=(20,10))

# %% [markdown]
# # Switched alphaHigh and betaHigh

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 

f = [forward.delta.mean(), forward.theta.mean(), forward.alphaLow.mean(), 
     forward.betaHigh.mean(), forward.betaLow.mean(), forward.alphaHigh.mean(), 
     forward.gammaLow.mean(), forward.gammaMid.mean()]

ra = [rest_android.delta.mean(), rest_android.theta.mean(), rest_android.alphaLow.mean(), 
     rest_android.betaHigh.mean(), rest_android.betaLow.mean(), rest_android.alphaHigh.mean(), 
     rest_android.gammaLow.mean(), rest_android.gammaMid.mean()]


index = ['delta', 'theta', 'alphaLow','alphaHigh', 'betaLow', 'betaHigh', 'gammaLow', 'gammaMid']

df = pd.DataFrame({'rest_android': ra, 'forward_android': f}, index=index)
ax = df.plot.bar(rot=0, figsize=(20,10))

# %%
f = [forward.betaHigh.mean(), forward.betaLow.mean(), forward.alphaHigh.mean(), 
     forward.gammaLow.mean(), forward.gammaMid.mean()]

ra = [rest_android.betaHigh.mean(), rest_android.betaLow.mean(), rest_android.alphaHigh.mean(), 
     rest_android.gammaLow.mean(), rest_android.gammaMid.mean()]


index = ['alphaHigh', 'betaLow', 'betaHigh', 'gammaLow', 'gammaMid']

df = pd.DataFrame({'rest_android': ra, 'forward_android': f}, index=index)
ax = df.plot.bar(rot=0, figsize=(20,10))

# %% [markdown]
# # First recording of forward showed better results, fatigue??

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 

f1 = [forward_android1.delta.mean(), forward_android1.theta.mean(), forward_android1.alphaLow.mean(), 
     forward_android1.betaHigh.mean(), forward_android1.betaLow.mean(), forward_android1.alphaHigh.mean(), 
     forward_android1.gammaLow.mean(), forward_android1.gammaMid.mean()]

f2 = [forward_android2.delta.mean(), forward_android2.theta.mean(), forward_android2.alphaLow.mean(), 
     forward_android2.betaHigh.mean(), forward_android2.betaLow.mean(), forward_android2.alphaHigh.mean(), 
     forward_android2.gammaLow.mean(), forward_android2.gammaMid.mean()]

f3 = [forward_android3.delta.mean(), forward_android3.theta.mean(), forward_android3.alphaLow.mean(), 
     forward_android3.betaHigh.mean(), forward_android3.betaLow.mean(), forward_android3.alphaHigh.mean(), 
     forward_android3.gammaLow.mean(), forward_android3.gammaMid.mean()]


index = ['delta', 'theta', 'alphaLow','alphaHigh', 'betaLow', 'betaHigh', 'gammaLow', 'gammaMid']

df = pd.DataFrame({'forward_android1': f1, 'forward_android2': f2, 'forward_android3': f3}, index=index)
ax = df.plot.bar(rot=0, figsize=(20,10))
